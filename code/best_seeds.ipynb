# %%
from plotly.subplots import make_subplots
from plotting import plot_values, update_layout
import glob
import plotly.graph_objects as go
import pandas as pd
import plotly.express as px
import json
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ### Get the names of all files we want to read

# %%
def get_best_reward(dir_path):
    try:
        x = pd.read_csv(os.path.join("..", dir_path, "log.txt"), sep="\t")
        return x["AverageReward"].max()
    except:
        print("?", dir_path)
        return -1

def label_algorithm(filter):
    if filter == "MeanStdFilter":
        return "ARS-v2"
    return "ARS-v1"

# %%
records = []
for experiment_file in glob.glob("../data/*/*/params.json", recursive=True):
    with open(experiment_file, "r", encoding="utf-8") as file:
        record = json.load(file)
        records.append(record)

all_data = pd.DataFrame.from_records(records)

# all_data = all_data[all_data.reward > 0]
all_data["task"] = all_data.env_name.str.replace("Safety", "").str.replace(
    "Velocity-v1", ""
)

all_data["algo"] = all_data["filter"].apply(label_algorithm)
# all_data["transform"] = all_data["transform"].apply(lambda x: x.split(":")[0])

all_data["reward"] = all_data.dir_path.apply(get_best_reward)
all_data['best_env_reward'] = 0
# all_data['best_env_reward'] = all_data.groupby(["task", "algo", "transform"]).reward.transform('max')
all_data.drop(
    ["best_env_reward",],
    axis=1,
    inplace=True,
)
all_data.drop("dir_path", axis=1)
# Out:
#      delta_std  deltas_used                      env_name         filter  \
# 0         0.02           40  SafetyHalfCheetahVelocity-v1       NoFilter
# 1         0.02           20  SafetyHalfCheetahVelocity-v1  MeanStdFilter
# 2         0.02           20  SafetyHalfCheetahVelocity-v1       NoFilter
# 3         0.02           20  SafetyHalfCheetahVelocity-v1  MeanStdFilter
# 4         0.02           40  SafetyHalfCheetahVelocity-v1  MeanStdFilter
# ..         ...          ...                           ...            ...
# 857       0.01           10      SafetySwimmerVelocity-v1  MeanStdFilter
# 858       0.01           30      SafetySwimmerVelocity-v1  MeanStdFilter
# 859       0.02           10      SafetySwimmerVelocity-v1  MeanStdFilter
# 860       0.02           10      SafetySwimmerVelocity-v1  MeanStdFilter
# 861       0.02           50      SafetySwimmerVelocity-v1  MeanStdFilter
#
#      n_directions  n_iter  n_workers policy_type  rollout_length  seed  shift  \
# 0              40    1000         10      linear            1000     1      0
# 1              80    1000         10      linear            1000     1      0
# 2              40    1000         10      linear            1000     5      0
# 3              40    1000         10      linear            1000     5      0
# 4              40    1000         10      linear            1000     1      0
# ..            ...     ...        ...         ...             ...   ...    ...
# 857            30    1000         10      linear            1000     3      0
# 858            50    1000         10      linear            1000     3      0
# 859            30    1000         10      linear            1000     1      0
# 860            30    1000         10      linear            1000     1      0
# 861            50    1000         10      linear            1000     1      0
#
#      step_size           transform         task    algo       reward
# 0         0.02         norm_clip:1  HalfCheetah  ARS-v1  3253.751523
# 1         0.02  component_clip:0.5  HalfCheetah  ARS-v2  6209.822468
# 2         0.02         norm_clip:1  HalfCheetah  ARS-v1  3838.236406
# 3         0.02  component_clip:0.5  HalfCheetah  ARS-v2  4221.828595
# 4         0.02              signed  HalfCheetah  ARS-v2  3371.637195
# ..         ...                 ...          ...     ...          ...
# 857       0.02         norm_clip:1      Swimmer  ARS-v2   355.178504
# 858       0.02  component_clip:0.5      Swimmer  ARS-v2   355.259914
# 859       0.02         norm_clip:1      Swimmer  ARS-v2   354.633987
# 860       0.02                none      Swimmer  ARS-v2   356.009718
# 861       0.02              signed      Swimmer  ARS-v2   357.610417
#
# [862 rows x 16 columns]

# %% [markdown]
# This data has the parameters for which it achieved the highest performance

# %%
all_data["best_reward"] = all_data.groupby(
    ["task", "algo", "transform"]
).reward.transform("max")

best_data = all_data[all_data.reward == all_data.best_reward].drop_duplicates(
    ["task", "algo", "transform"], keep="first", ignore_index=True
).drop(["reward", "best_reward", "dir_path", "seed"], axis=1)
best_data
# Out:
#     delta_std  deltas_used                      env_name         filter  \
# 0       0.020           20  SafetyHalfCheetahVelocity-v1  MeanStdFilter
# 1       0.020           20  SafetyHalfCheetahVelocity-v1       NoFilter
# 2       0.020           20  SafetyHalfCheetahVelocity-v1  MeanStdFilter
# 3       0.020           20  SafetyHalfCheetahVelocity-v1       NoFilter
# 4       0.020           20  SafetyHalfCheetahVelocity-v1       NoFilter
# 5       0.020           20  SafetyHalfCheetahVelocity-v1  MeanStdFilter
# 6       0.020           20  SafetyHalfCheetahVelocity-v1       NoFilter
# 7       0.020           20  SafetyHalfCheetahVelocity-v1  MeanStdFilter
# 8       0.025           40     SafetyWalker2dVelocity-v1       NoFilter
# 9       0.025           40     SafetyWalker2dVelocity-v1  MeanStdFilter
# 10      0.025           40     SafetyWalker2dVelocity-v1       NoFilter
# 11      0.025           40     SafetyWalker2dVelocity-v1  MeanStdFilter
# 12      0.025           40     SafetyWalker2dVelocity-v1  MeanStdFilter
# 13      0.025           40     SafetyWalker2dVelocity-v1  MeanStdFilter
# 14      0.025           40     SafetyWalker2dVelocity-v1       NoFilter
# 15      0.025           40     SafetyWalker2dVelocity-v1       NoFilter
# 16      0.010          230     SafetyHumanoidVelocity-v1       NoFilter
# 17      0.010          350     SafetyHumanoidVelocity-v1       NoFilter
# 18      0.010          350     SafetyHumanoidVelocity-v1       NoFilter
# 19      0.010          230     SafetyHumanoidVelocity-v1  MeanStdFilter
# 20      0.010          350     SafetyHumanoidVelocity-v1       NoFilter
# 21      0.010          230     SafetyHumanoidVelocity-v1  MeanStdFilter
# 22      0.010          230     SafetyHumanoidVelocity-v1  MeanStdFilter
# 23      0.010          230     SafetyHumanoidVelocity-v1  MeanStdFilter
# 24      0.020           60          SafetyAntVelocity-v1       NoFilter
# 25      0.020           20          SafetyAntVelocity-v1  MeanStdFilter
# 26      0.020           40          SafetyAntVelocity-v1  MeanStdFilter
# 27      0.020           20          SafetyAntVelocity-v1       NoFilter
# 28      0.020           20          SafetyAntVelocity-v1       NoFilter
# 29      0.020           20          SafetyAntVelocity-v1  MeanStdFilter
# 30      0.020           20          SafetyAntVelocity-v1       NoFilter
# 31      0.020           20          SafetyAntVelocity-v1  MeanStdFilter
# 32      0.030            8       SafetyHopperVelocity-v1  MeanStdFilter
# 33      0.020            8       SafetyHopperVelocity-v1       NoFilter
# 34      0.030            8       SafetyHopperVelocity-v1  MeanStdFilter
# 35      0.030            8       SafetyHopperVelocity-v1       NoFilter
# 36      0.020            8       SafetyHopperVelocity-v1       NoFilter
# 37      0.030            8       SafetyHopperVelocity-v1       NoFilter
# 38      0.030            8       SafetyHopperVelocity-v1  MeanStdFilter
# 39      0.020            8       SafetyHopperVelocity-v1  MeanStdFilter
# 40      0.020           30      SafetySwimmerVelocity-v1       NoFilter
# 41      0.020           30      SafetySwimmerVelocity-v1  MeanStdFilter
# 42      0.020           10      SafetySwimmerVelocity-v1       NoFilter
# 43      0.020           30      SafetySwimmerVelocity-v1  MeanStdFilter
# 44      0.020           10      SafetySwimmerVelocity-v1  MeanStdFilter
# 45      0.020           10      SafetySwimmerVelocity-v1  MeanStdFilter
# 46      0.020           30      SafetySwimmerVelocity-v1       NoFilter
# 47      0.020           10      SafetySwimmerVelocity-v1       NoFilter
#
#     n_directions  n_iter  n_workers policy_type  rollout_length  shift  \
# 0             80    1000         10      linear            1000      0
# 1            120    1000         10      linear            1000      0
# 2             80    1000         10      linear            1000      0
# 3             80    1000         10      linear            1000      0
# 4             40    1000         10      linear            1000      0
# 5             80    1000         10      linear            1000      0
# 6            120    1000         10      linear            1000      0
# 7             40    1000         10      linear            1000      0
# 8             80    1000         10      linear            1000      1
# 9             80    1000         10      linear            1000      1
# 10           100    1000         10      linear            1000      1
# 11            80    1000         10      linear            1000      1
# 12            80    1000         10      linear            1000      1
# 13           100    1000         10      linear            1000      1
# 14            80    1000         10      linear            1000      1
# 15            80    1000         10      linear            1000      1
# 16           350    1000         10      linear            1000      5
# 17           350    1000         10      linear            1000      5
# 18           350    1000         10      linear            1000      5
# 19           350    1000         10      linear            1000      5
# 20           350    1000         10      linear            1000      5
# 21           350    1000         10      linear            1000      5
# 22           350    1000         10      linear            1000      5
# 23           350    1000         10      linear            1000      5
# 24            80    1000         10      linear            1000      1
# 25            80    1000         10      linear            1000      1
# 26            80    1000         10      linear            1000      1
# 27            80    1000         10      linear            1000      1
# 28            80    1000         10      linear            1000      1
# 29            80    1000         10      linear            1000      1
# 30            80    1000         10      linear            1000      1
# 31            80    1000         10      linear            1000      1
# 32            32    1000         10      linear            1000      1
# 33            32    1000         10      linear            1000      1
# 34            32    1000         10      linear            1000      1
# 35            32    1000         10      linear            1000      1
# 36            16    1000         10      linear            1000      1
# 37            16    1000         10      linear            1000      1
# 38            16    1000         10      linear            1000      1
# 39            32    1000         10      linear            1000      1
# 40            30    1000         10      linear            1000      0
# 41            50    1000         10      linear            1000      0
# 42            50    1000         10      linear            1000      0
# 43            30    1000         10      linear            1000      0
# 44            30    1000         10      linear            1000      0
# 45            50    1000         10      linear            1000      0
# 46            30    1000         10      linear            1000      0
# 47            30    1000         10      linear            1000      0
#
#     step_size           transform         task    algo
# 0        0.02  component_clip:0.5  HalfCheetah  ARS-v2
# 1        0.02                none  HalfCheetah  ARS-v1
# 2        0.02                none  HalfCheetah  ARS-v2
# 3        0.02              signed  HalfCheetah  ARS-v1
# 4        0.02         norm_clip:1  HalfCheetah  ARS-v1
# 5        0.02         norm_clip:1  HalfCheetah  ARS-v2
# 6        0.02  component_clip:0.5  HalfCheetah  ARS-v1
# 7        0.02              signed  HalfCheetah  ARS-v2
# 8        0.02                none     Walker2d  ARS-v1
# 9        0.03                none     Walker2d  ARS-v2
# 10       0.02         norm_clip:1     Walker2d  ARS-v1
# 11       0.03         norm_clip:1     Walker2d  ARS-v2
# 12       0.03  component_clip:0.5     Walker2d  ARS-v2
# 13       0.02              signed     Walker2d  ARS-v2
# 14       0.03  component_clip:0.5     Walker2d  ARS-v1
# 15       0.02              signed     Walker2d  ARS-v1
# 16       0.01                none     Humanoid  ARS-v1
# 17       0.01  component_clip:0.5     Humanoid  ARS-v1
# 18       0.01         norm_clip:1     Humanoid  ARS-v1
# 19       0.01                none     Humanoid  ARS-v2
# 20       0.01              signed     Humanoid  ARS-v1
# 21       0.01  component_clip:0.5     Humanoid  ARS-v2
# 22       0.01              signed     Humanoid  ARS-v2
# 23       0.01         norm_clip:1     Humanoid  ARS-v2
# 24       0.02  component_clip:0.5          Ant  ARS-v1
# 25       0.02  component_clip:0.5          Ant  ARS-v2
# 26       0.02                none          Ant  ARS-v2
# 27       0.02         norm_clip:1          Ant  ARS-v1
# 28       0.02              signed          Ant  ARS-v1
# 29       0.02              signed          Ant  ARS-v2
# 30       0.02                none          Ant  ARS-v1
# 31       0.02         norm_clip:1          Ant  ARS-v2
# 32       0.02                none       Hopper  ARS-v2
# 33       0.02         norm_clip:1       Hopper  ARS-v1
# 34       0.02  component_clip:0.5       Hopper  ARS-v2
# 35       0.02  component_clip:0.5       Hopper  ARS-v1
# 36       0.02              signed       Hopper  ARS-v1
# 37       0.02                none       Hopper  ARS-v1
# 38       0.02         norm_clip:1       Hopper  ARS-v2
# 39       0.02              signed       Hopper  ARS-v2
# 40       0.02         norm_clip:1      Swimmer  ARS-v1
# 41       0.02              signed      Swimmer  ARS-v2
# 42       0.02                none      Swimmer  ARS-v1
# 43       0.02         norm_clip:1      Swimmer  ARS-v2
# 44       0.02  component_clip:0.5      Swimmer  ARS-v2
# 45       0.02                none      Swimmer  ARS-v2
# 46       0.02  component_clip:0.5      Swimmer  ARS-v1
# 47       0.02              signed      Swimmer  ARS-v1

# %%
best_data.shape
# Out:
# (48, 14)

# %%
def to_run(seed_list):
    return [seed for seed in range(6) if seed not in seed_list][1:]

def label_filter(algo):
    if algo == "ARS-v1":
        return "NoFilter"
    return "MeanStdFilter"

df = best_data.merge(all_data, "inner", list(best_data)).groupby(list(best_data), as_index=False)[["seed"]].agg(list)
df = df[df["transform"].isin(["none", "component_clip:0.5"])].reset_index(drop=True)
df["seed"] = df["seed"].apply(to_run)
df = df[df.seed.apply(len) > 0]
print(df.seed.apply(len).sum())
df = df.explode("seed", ignore_index=True)

df["env_name"] = df.task.apply(lambda x: f"Safety{x}Velocity-v1")
df["filter"] = df["algo"].apply(label_filter)
df.drop(["task", "algo"], axis=1, inplace=True)
print(df.shape)
df.env_name.value_counts()
# Out:
# 0
# (0, 13)
# Series([], Name: count, dtype: int64)

# %%
df.to_json("../to_run.json", orient="records", indent=4)
